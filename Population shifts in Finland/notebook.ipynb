# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Load dataset

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    Year  Live births  Deaths  Natural increase  Intermunicipal migration  \
# 0  1970        64559   44119             20440                    218979
# 1  1971        61067   45876             15191                    220199
# 2  1972        58864   43958             14906                    234818
# 3  1973        56787   43410             13377                    246168
# 4  1974        62472   44676             17796                    276034
#
#    Immigration to Finland  Emigration from Finland  Net migration  Marriages  \
# 0                   16824                    53205         -36381      40730
# 1                   18338                    17665            673      37925
# 2                   17421                    11951           5470      35467
# 3                   16491                    10309           6182      34883
# 4                   13311                    12027           1284      34533
#
#    Divorces  Total change  Population
# 0      6044        -15941     4598336
# 1      7175         27576     4625912
# 2      8254         27489     4653401
# 3      8831         25360     4678761
# 4     10019         23626     4702387

# %% [markdown]
# CLeaning - remove spaces

# %%
df.columns = df.columns.str.strip()
df = df.sort_values("Year")

# %% [markdown]
# population over time graph

# %%
plt.figure()
plt.plot(df["Year"], df["Population"])
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population of Finland Over Time")
plt.show()

# %% [markdown]
# Births vs Deaths

# %%
plt.figure()
plt.plot(df["Year"], df["Live births"], label="Births")
plt.plot(df["Year"], df["Deaths"], label="Deaths")
plt.legend()
plt.xlabel("Year")
plt.ylabel("Count")
plt.title("Births vs Deaths Over Time")
plt.show()

# %% [markdown]
# Migration trends

# %%
plt.figure()
plt.plot(df["Year"], df["Net migration"], label="Net Migration")
plt.xlabel("Year")
plt.ylabel("People")
plt.title("Net Migration Over Time")
plt.legend()
plt.show()

# %% [markdown]
# Natural increase

# %%
plt.figure()
plt.plot(df["Year"], df["Natural increase"])
plt.xlabel("Year")
plt.ylabel("Population Change")
plt.title("Natural Population Increase (Births - Deaths)")
plt.show()

# %% [markdown]
# Compare drivers of population change

# %%
plt.figure()
plt.plot(df["Year"], df["Natural increase"], label="Natural Increase")
plt.plot(df["Year"], df["Net migration"], label="Net Migration")
plt.legend()
plt.title("Population Change Drivers")
plt.xlabel("Year")
plt.ylabel("Change")
plt.show()

# %% [markdown]
# Total population change

# %%
plt.figure()
plt.plot(df["Year"], df["Total change"])
plt.title("Total Population Change Per Year")
plt.xlabel("Year")
plt.ylabel("Change")
plt.show()

# %% [markdown]
# Correlation

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title("Feature Correlation")
plt.show()

# %% [markdown]
# ## Building model
