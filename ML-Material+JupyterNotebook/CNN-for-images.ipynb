# %% [markdown]
# ### CNNs for Images

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load dataset for teaching model

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# filtering classes(keeping only 7 and 9). adding chanale 1. normalization to 0-1.

# %%
train_mask = np.isin(y_train, [7, 9])
test_mask = np.isin(y_test, [7, 9])

x_train = x_train[train_mask][..., None]/255.0
y_train = (y_train[train_mask] == 9).astype(np.float32) # 1 if class 9 else 0

x_test = x_test[test_mask][..., None]/255.0
y_test = (y_test[test_mask] == 9).astype(np.float32)

# %% [markdown]
# creating small CNN. conv2D - searching for edges. MaxPool - makes image smaller, keeps everything nessasary. Flatten - makes vector. Dense(1, sigmoid) - probability: 0 sneaker, 1 - ankle boot.

# %%
model = tf.keras.Sequential([
 tf.keras.layers.Input(shape=(28,28,1)),
 
 tf.keras.layers.Conv2D(32, 3, activation="relu"),
 tf.keras.layers.MaxPool2D(),

 tf.keras.layers.Conv2D(64, 3, activation="relu"),
 tf.keras.layers.MaxPool2D(),

 tf.keras.layers.Flatten(),
 tf.keras.layers.Dense(64, activation="relu"),
 tf.keras.layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# compile: binary_crossentory because 2 classes.

# %%
model.compile(
 loss="binary_crossentropy",
 optimizer="adam",
 metrics=["accuracy"]
)

# %% [markdown]
# Fit

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split=0.1, verbose=0)

# %% [markdown]
# evaluate on test

# %%
loss, acc = model.evaluate(x_test, y_test, verbose=0)
print("Test accuracy:", acc)
# Out:
# Test accuracy: 0.9745000004768372
